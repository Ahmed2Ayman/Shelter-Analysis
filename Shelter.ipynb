# %%
import pandas as pd
df=pd.read_csv("/content/homelessness_shelter_data.csv")

# %%
print(df.head())
# Out:
#    id        date     shelter_name         city state  total_capacity  \
# 0   1  2023-10-05  Sunrise Shelter       Dallas    TX              85
# 1   2  2023-08-01       Safe Haven       Dallas    TX             128
# 2   3  2025-04-27    Second Chance     San Jose    CA             190
# 3   4  2024-10-05      Harbor Home     San Jose    CA             115
# 4   5  2024-09-15      Harbor Home  San Antonio    TX             155
#
#    occupied_beds  available_beds  occupancy_rate  average_age  \
# 0             62              23            72.9           19
# 1            117              11            91.4           58
# 2            144              46            75.8           56
# 3              7             108             6.1           63
# 4             65              90            41.9           21
#
#    male_percentage  female_percentage  season                notes
# 0               43                 57  Spring          High demand
# 1               45                 55  Summer   No issues reported
# 2               52                 48  Summer  Excellent condition
# 3               48                 52  Autumn    Needs maintenance
# 4               48                 52  Summer   No issues reported

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of        id        date     shelter_name          city state  total_capacity  \
# 0       1  2023-10-05  Sunrise Shelter        Dallas    TX              85
# 1       2  2023-08-01       Safe Haven        Dallas    TX             128
# 2       3  2025-04-27    Second Chance      San Jose    CA             190
# 3       4  2024-10-05      Harbor Home      San Jose    CA             115
# 4       5  2024-09-15      Harbor Home   San Antonio    TX             155
# ..    ...         ...              ...           ...   ...             ...
# 995   996  2023-11-14   New Beginnings      San Jose    CA             205
# 996   997  2025-03-09      Harbor Home      San Jose    CA              60
# 997   998  2025-06-09    Pathway Place        Dallas    TX              54
# 998   999  2023-09-05       Hope House     San Diego    CA             268
# 999  1000  2024-06-24   New Beginnings  Philadelphia    PA             177
#
#      occupied_beds  available_beds  occupancy_rate  average_age  \
# 0               62              23            72.9           19
# 1              117              11            91.4           58
# 2              144              46            75.8           56
# 3                7             108             6.1           63
# 4               65              90            41.9           21
# ..             ...             ...             ...          ...
# 995            199               6            97.1           45
# 996             16              44            26.7           59
# 997             26              28            48.1           52
# 998            259               9            96.6           45
# 999             63             114            35.6           60
#
#      male_percentage  female_percentage  season                notes
# 0                 43                 57  Spring          High demand
# 1                 45                 55  Summer   No issues reported
# 2                 52                 48  Summer  Excellent condition
# 3                 48                 52  Autumn    Needs maintenance
# 4                 48                 52  Summer   No issues reported
# ..               ...                ...     ...                  ...
# 995               53                 47  Winter   Recently renovated
# 996               48                 52  Spring    Needs maintenance
# 997               52                 48  Spring     Under inspection
# 998               56                 44  Spring   Recently renovated
# 999               66                 34  Summer          High demand
#
# [1000 rows x 14 columns]>

# %%
print(df.describe())
# Out:
#                 id  total_capacity  occupied_beds  available_beds  \
# count  1000.000000     1000.000000    1000.000000     1000.000000
# mean    500.500000      179.123000      91.874000       87.249000
# std     288.819436       73.419195      67.068937       65.531224
# min       1.000000       50.000000       0.000000        0.000000
# 25%     250.750000      115.000000      38.000000       35.000000
# 50%     500.500000      182.000000      76.000000       71.000000
# 75%     750.250000      243.000000     136.000000      128.250000
# max    1000.000000      300.000000     294.000000      296.000000
#
#        occupancy_rate  average_age  male_percentage  female_percentage
# count     1000.000000  1000.000000      1000.000000        1000.000000
# mean        51.214700    42.037000        54.634000          45.366000
# std         28.880331    13.768122         8.797468           8.797468
# min          0.000000    18.000000        40.000000          30.000000
# 25%         26.775000    30.000000        47.000000          38.000000
# 50%         51.850000    42.000000        55.000000          45.000000
# 75%         76.800000    54.000000        62.000000          53.000000
# max        100.000000    65.000000        70.000000          60.000000

# %%
df.columns=df.columns.str.strip()
print(df.head)
# Out:
# <bound method NDFrame.head of        id        date     shelter_name          city state  total_capacity  \
# 0       1  2023-10-05  Sunrise Shelter        Dallas    TX              85
# 1       2  2023-08-01       Safe Haven        Dallas    TX             128
# 2       3  2025-04-27    Second Chance      San Jose    CA             190
# 3       4  2024-10-05      Harbor Home      San Jose    CA             115
# 4       5  2024-09-15      Harbor Home   San Antonio    TX             155
# ..    ...         ...              ...           ...   ...             ...
# 995   996  2023-11-14   New Beginnings      San Jose    CA             205
# 996   997  2025-03-09      Harbor Home      San Jose    CA              60
# 997   998  2025-06-09    Pathway Place        Dallas    TX              54
# 998   999  2023-09-05       Hope House     San Diego    CA             268
# 999  1000  2024-06-24   New Beginnings  Philadelphia    PA             177
#
#      occupied_beds  available_beds  occupancy_rate  average_age  \
# 0               62              23            72.9           19
# 1              117              11            91.4           58
# 2              144              46            75.8           56
# 3                7             108             6.1           63
# 4               65              90            41.9           21
# ..             ...             ...             ...          ...
# 995            199               6            97.1           45
# 996             16              44            26.7           59
# 997             26              28            48.1           52
# 998            259               9            96.6           45
# 999             63             114            35.6           60
#
#      male_percentage  female_percentage  season                notes
# 0                 43                 57  Spring          High demand
# 1                 45                 55  Summer   No issues reported
# 2                 52                 48  Summer  Excellent condition
# 3                 48                 52  Autumn    Needs maintenance
# 4                 48                 52  Summer   No issues reported
# ..               ...                ...     ...                  ...
# 995               53                 47  Winter   Recently renovated
# 996               48                 52  Spring    Needs maintenance
# 997               52                 48  Spring     Under inspection
# 998               56                 44  Spring   Recently renovated
# 999               66                 34  Summer          High demand
#
# [1000 rows x 14 columns]>

# %%
df["date"]=pd.to_datetime(df['date'])

# %%
df.dropna()
# Out:
#        id       date     shelter_name          city state  total_capacity  \
# 0       1 2023-10-05  Sunrise Shelter        Dallas    TX              85
# 1       2 2023-08-01       Safe Haven        Dallas    TX             128
# 2       3 2025-04-27    Second Chance      San Jose    CA             190
# 3       4 2024-10-05      Harbor Home      San Jose    CA             115
# 4       5 2024-09-15      Harbor Home   San Antonio    TX             155
# ..    ...        ...              ...           ...   ...             ...
# 995   996 2023-11-14   New Beginnings      San Jose    CA             205
# 996   997 2025-03-09      Harbor Home      San Jose    CA              60
# 997   998 2025-06-09    Pathway Place        Dallas    TX              54
# 998   999 2023-09-05       Hope House     San Diego    CA             268
# 999  1000 2024-06-24   New Beginnings  Philadelphia    PA             177
#
#      occupied_beds  available_beds  occupancy_rate  average_age  \
# 0               62              23            72.9           19
# 1              117              11            91.4           58
# 2              144              46            75.8           56
# 3                7             108             6.1           63
# 4               65              90            41.9           21
# ..             ...             ...             ...          ...
# 995            199               6            97.1           45
# 996             16              44            26.7           59
# 997             26              28            48.1           52
# 998            259               9            96.6           45
# 999             63             114            35.6           60
#
#      male_percentage  female_percentage  season                notes
# 0                 43                 57  Spring          High demand
# 1                 45                 55  Summer   No issues reported
# 2                 52                 48  Summer  Excellent condition
# 3                 48                 52  Autumn    Needs maintenance
# 4                 48                 52  Summer   No issues reported
# ..               ...                ...     ...                  ...
# 995               53                 47  Winter   Recently renovated
# 996               48                 52  Spring    Needs maintenance
# 997               52                 48  Spring     Under inspection
# 998               56                 44  Spring   Recently renovated
# 999               66                 34  Summer          High demand
#
# [913 rows x 14 columns]

# %%
df.drop_duplicates()
# Out:
#        id       date     shelter_name          city state  total_capacity  \
# 0       1 2023-10-05  Sunrise Shelter        Dallas    TX              85
# 1       2 2023-08-01       Safe Haven        Dallas    TX             128
# 2       3 2025-04-27    Second Chance      San Jose    CA             190
# 3       4 2024-10-05      Harbor Home      San Jose    CA             115
# 4       5 2024-09-15      Harbor Home   San Antonio    TX             155
# ..    ...        ...              ...           ...   ...             ...
# 995   996 2023-11-14   New Beginnings      San Jose    CA             205
# 996   997 2025-03-09      Harbor Home      San Jose    CA              60
# 997   998 2025-06-09    Pathway Place        Dallas    TX              54
# 998   999 2023-09-05       Hope House     San Diego    CA             268
# 999  1000 2024-06-24   New Beginnings  Philadelphia    PA             177
#
#      occupied_beds  available_beds  occupancy_rate  average_age  \
# 0               62              23            72.9           19
# 1              117              11            91.4           58
# 2              144              46            75.8           56
# 3                7             108             6.1           63
# 4               65              90            41.9           21
# ..             ...             ...             ...          ...
# 995            199               6            97.1           45
# 996             16              44            26.7           59
# 997             26              28            48.1           52
# 998            259               9            96.6           45
# 999             63             114            35.6           60
#
#      male_percentage  female_percentage  season                notes
# 0                 43                 57  Spring          High demand
# 1                 45                 55  Summer   No issues reported
# 2                 52                 48  Summer  Excellent condition
# 3                 48                 52  Autumn    Needs maintenance
# 4                 48                 52  Summer   No issues reported
# ..               ...                ...     ...                  ...
# 995               53                 47  Winter   Recently renovated
# 996               48                 52  Spring    Needs maintenance
# 997               52                 48  Spring     Under inspection
# 998               56                 44  Spring   Recently renovated
# 999               66                 34  Summer          High demand
#
# [1000 rows x 14 columns]

# %%
shelter_dim = df[['shelter_name', 'city', 'state', 'notes']].drop_duplicates().copy()
shelter_dim['shelter_id'] = shelter_dim.index + 1

# %%
shelter_dim
# Out:
#         shelter_name          city state                notes  shelter_id
# 0    Sunrise Shelter        Dallas    TX          High demand           1
# 1         Safe Haven        Dallas    TX   No issues reported           2
# 2      Second Chance      San Jose    CA  Excellent condition           3
# 3        Harbor Home      San Jose    CA    Needs maintenance           4
# 4        Harbor Home   San Antonio    TX   No issues reported           5
# ..               ...           ...   ...                  ...         ...
# 990       Hope House   Los Angeles    CA                  NaN         991
# 992  Sunrise Shelter   San Antonio    TX   No issues reported         993
# 993      Harbor Home      San Jose    CA       Staff shortage         994
# 998       Hope House     San Diego    CA   Recently renovated         999
# 999   New Beginnings  Philadelphia    PA          High demand        1000
#
# [608 rows x 5 columns]

# %%
season_dim=df[["season"]].drop_duplicates().copy()
season_dim['season_id']=season_dim.index+1

# %%
date_dim=df[['date']].drop_duplicates().copy()
date_dim['date_id']=date_dim.index+1
date_dim['year']=date_dim['date'].dt.year
date_dim['month']=date_dim['date'].dt.month
date_dim['day']=date_dim['date'].dt.day
date_dim['weakday']=date_dim['date'].dt.day_name()

# %%
date_dim
# Out:
#           date  date_id  year  month  day day_of_week
# 0   2023-10-05        1  2023     10    5    Thursday
# 1   2023-08-01        2  2023      8    1     Tuesday
# 2   2025-04-27        3  2025      4   27      Sunday
# 3   2024-10-05        4  2024     10    5    Saturday
# 4   2024-09-15        5  2024      9   15      Sunday
# ..         ...      ...   ...    ...  ...         ...
# 976 2024-11-02      977  2024     11    2    Saturday
# 978 2023-11-20      979  2023     11   20      Monday
# 981 2023-10-29      982  2023     10   29      Sunday
# 985 2024-12-12      986  2024     12   12    Thursday
# 993 2024-11-30      994  2024     11   30    Saturday
#
# [533 rows x 6 columns]

# %%
shelter_occupancy=df.copy()
shelter_occupancy=shelter_occupancy.merge(shelter_dim,on=['shelter_name', 'city', 'state', 'notes'])
shelter_occupancy=shelter_occupancy.merge(season_dim,on='season')
shelter_occupancy=shelter_occupancy.merge(date_dim,on='date')
shelter_occupancy_fact=shelter_occupancy[['id', 'shelter_id', 'season_id', 'date_id',
                      'total_capacity', 'occupied_beds', 'available_beds',
                      'occupancy_rate', 'average_age', 'male_percentage', 'female_percentage']]

# %%
shelter_occupancy_fact
# Out:
#        id  shelter_id  season_id  date_id  total_capacity  occupied_beds  \
# 0       1           1          1        1              85             62
# 1       2           2          2        2             128            117
# 2       3           3          2        3             190            144
# 3       4           4          4        4             115              7
# 4       5           5          2        5             155             65
# ..    ...         ...        ...      ...             ...            ...
# 995   996         861         13      570             205            199
# 996   997           4          1      910              60             16
# 997   998         908          1      594              54             26
# 998   999         999          1      539             268            259
# 999  1000        1000          2       33             177             63
#
#      available_beds  occupancy_rate  average_age  male_percentage  \
# 0                23            72.9           19               43
# 1                11            91.4           58               45
# 2                46            75.8           56               52
# 3               108             6.1           63               48
# 4                90            41.9           21               48
# ..              ...             ...          ...              ...
# 995               6            97.1           45               53
# 996              44            26.7           59               48
# 997              28            48.1           52               52
# 998               9            96.6           45               56
# 999             114            35.6           60               66
#
#      female_percentage
# 0                   57
# 1                   55
# 2                   48
# 3                   52
# 4                   52
# ..                 ...
# 995                 47
# 996                 52
# 997                 48
# 998                 44
# 999                 34
#
# [1000 rows x 11 columns]

# %%
shelter_occupancy_fact.to_csv("shelter_occupancy_fact.csv", index=False)
date_dim.to_csv("date_dim.csv", index=False)
shelter_dim.to_csv("shelter_dim.csv", index=False)
season_dim.to_csv("season_dim.csv", index=False)

# %%
import pandas as pd

# --- 1. LOAD AND CLEAN DATA ---
print("Loading and cleaning the dataset...")
# Load the dataset
df = pd.read_csv("/content/homelessness_shelter_data.csv")
# Out:
# Loading and cleaning the dataset...

# %%
df.columns = df.columns.str.strip()

# %%
# Convert 'date' column to a proper datetime format
df["date"] = pd.to_datetime(df['date'])

# %%
# IMPORTANT FIX: Remove duplicate rows and save the result
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True) # Reset index after dropping rows
print("Data cleaning complete.")
# Out:
# Data cleaning complete.

# %%
# Shelter Dimension
shelter_dim = df[['shelter_name', 'city', 'state', 'notes']].drop_duplicates().reset_index(drop=True)
shelter_dim.insert(0, 'shelter_id', shelter_dim.index + 1)
print("\nShelter Dimension Table created.")
# Out:
# Shelter Dimension Table created.

# %%
# Season Dimension
season_dim = df[["season"]].drop_duplicates().reset_index(drop=True)
season_dim.insert(0, 'season_id', season_dim.index + 1)
print("Season Dimension Table created.")
# Out:
# Season Dimension Table created.

# %%
# CRITICAL FIX: Create the Date Dimension Table
date_dim = pd.DataFrame({'date': df['date'].unique()})
date_dim.sort_values(by='date', inplace=True)
date_dim.reset_index(drop=True, inplace=True)
date_dim.insert(0, 'date_id', date_dim.index + 1)
# Add useful date components for analysis
date_dim['year'] = date_dim['date'].dt.year
date_dim['month'] = date_dim['date'].dt.month
date_dim['day'] = date_dim['date'].dt.day
date_dim['day_of_week'] = date_dim['date'].dt.day_name()
print("Date Dimension Table created.")
# Out:
# Date Dimension Table created.

# %%
# Merge dimension keys back into the main DataFrame
fact_df = df.merge(shelter_dim, on=['shelter_name', 'city', 'state', 'notes'])
fact_df = fact_df.merge(season_dim, on='season')
fact_df = fact_df.merge(date_dim, on='date')

# %%
shelter_occupancy_fact = fact_df[[
    'id', 'shelter_id', 'season_id', 'date_id',
    'total_capacity', 'occupied_beds', 'available_beds',
    'occupancy_rate', 'average_age', 'male_percentage', 'female_percentage'
]].rename(columns={'id': 'occupancy_id'})
print("\nShelter Occupancy Fact Table created.")
# Out:
# Shelter Occupancy Fact Table created.

# %%
shelter_occupancy_fact.to_csv("shelter_occupancy_fact.csv", index=False)
date_dim.to_csv("date_dim.csv", index=False)
shelter_dim.to_csv("shelter_dim.csv", index=False)
season_dim.to_csv("season_dim.csv", index=False)
print("\nCSV files saved and ready for upload!")
# Out:
# CSV files saved and ready for upload!
